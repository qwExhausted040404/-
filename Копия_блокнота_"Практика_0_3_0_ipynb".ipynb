# %% [markdown]
# <a href="https://colab.research.google.com/github/qwExhausted040404/-/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B0_0_3_0_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Тумаков Тимофей Кириллович

# %% [markdown]
# **Во всей практике нельзя применять библиотеки предоставляющие готовые решения!**

# %% [markdown]
# # **Задача 1.**

# %% [markdown]
# Типы данных Напишите программу на Python, которая принимает список чисел в качестве входных данных от пользователя, а затем выводит сумму, среднее значение и максимальное значение из списка.
#
# ***Нельзя использовать: len(), min(), max(), average(), sum()***
#
# Ввод:
# ```
# 1 2 3 4 5 6 7
# ```
# Вывод:
#
# ```
# Сумма чисел: 28
# Среднее арифм.: 4.0
# Максимальное значение: 7
# ```

# %%
a=list(input('введите числа через пробел: ').split(' '))
a1=[]
sm=0
k=0
for i in a:
  a1.append(int(i))
  k+=1
for j in a1:
    sm+=j
mx=-1000
for l in a1:
  if int(l)>mx:
    mx=int(l)
  else:
    mx=mx
print('сумма = ', sm)
print('среднее арифметическое = ', sm/k)
print('максимальное значение = ', mx)
# Out:
# введите числа через пробел: 5 36 853
# сумма =  894
# среднее арифметическое =  298.0
# максимальное значение =  853

# %% [markdown]
# # **Задача 2.**

# %% [markdown]
# Напишите программу на Python, которая принимает список слов в качестве входных данных от пользователя, а затем распечатывает список в обратном порядке.
#
# Ввод:
#
# ```
# апельсин мандарин яблоко
# ```
#
# Вывод:
#
# ```
# яблоко мандарин апельсин
# ```

# %%
a=list(input('введите слова: ').split(' '))
a1=[]
for i in range(1, len(a)+1):
  a1.append(a[-(i)])
A1=''
for i in a1:
  A1+=i + ' '
print(A1)
# далее если срезы можно, a len() нельзя :)
'''
a1=a[::-1]
A1=''
for i in a1:
  A1+=i + ' '
print(A1)
'''
# Out:
# введите слова: да нет мб хз
# хз мб нет да
# "\na1=a[::-1]\nA1=''\nfor i in a1:\n  A1+=i + ' '\nprint(A1)\n"

# %% [markdown]
# # **Задача 3**

# %% [markdown]
# Простой чат-бот
# Создайте простого чат-бота, который отвечает на основные запросы пользователей. Программа должна использовать условные выражения для определения намерений пользователя и последующего соответствующего ответа.
#
# Чат бот может:
#
# - помогать складывать числа
# - подсказывать фильм, музыку и тд (из заранее созданного списка)
# - создавать список дел (а также выводить его, обновлять, очищать)
#
# Интерфейс чат-бота на ваше усмотрение, это могут быть как заранее определенные команды, так и к примеру вызов команды по номеру
#
# *Реализовать без использования функций*
#
# Пример:
#
# Ввод:
#
# ```
# Олег, какую мызыку посоветуешь?
# ```
#
# Вывод:
#
# ```
# Я бы посоветовал вам: Led Zeppelin Stairway to Heaven
# ```

# %%
from random import *
h=''
while True:
  a=input('Здравствуйте, что я могу для вас сделать? 1) посоветуй музыку 2) посоветуй фильм 3) сложи числа 4) составь мне список дел на сегодня ')
  movies=['Гарри Поттер', 'Брюс Всемогущий', 'Шоу Трумана', 'Браби', 'Платформа', 'Запрос в друзья', 'Я легенда', 'Война миров z', 'Пункт назначения']
  music=['Love Me', 'Seventh Heaven', 'All You Need Is Love', 'Mockingbird', 'What I Meant To Say', 'The Winner Takes It All', 'Should I Stay Or Should I Go', 'Let It Be', 'Farewell']
  if a=='1':
    print('Я бы посоветовал вам: ', choice(music))
  if a=='2':
    print('Я бы посоветовал вам фильм: ', choice(movies))
  if a=='3':
    a1=list(input('Введите через пробел числа, которые нужно сложить: ').split(' '))
    print(int(a1[0])+int(a1[1]))
  if a=='4':
    print('Ваш список дел на данный момент: ', h)
    A1=input('что вы хотите сделать со списком дел? 1)создать 2)вывести 3)очистить 4)обновить ')
    if A1=='1':
      A=list(input('Создайте список дел через запятую: ').split(','))
      k=0 # далле в каждом пункте я создаю переменну к, чтобы контролировать правильную расстановку запятых
      for i in A:
        if k>=1:
          h=h+', '+i
        else:
          h+=i
        k+=1
    if A1=='2':
      h=''
      k=0
      for i in A:
        if k>=1:
          h=h+', '+i
        else:
          h+=i
        k+=1
      print('Ваш список дел: ', h)
    if A1=='3':
      h=''
      print('Ваш список дел: ', h)
    if A1=='4':
      A2=list(input('Что хотите добавить в список дел? ').split(','))
      A=A+A2
      h=''
      k=0
      for i in A:
          if k>=1:
            h=h+', '+i
          else:
            h+=i
          k+=1
      print('Ваш список дел: ', h)
# Out:
# Здравствуйте, что я могу для вас сделать? 1) посоветуй музыку 2) посоветуй фильм 3) сложи числа 4) составь мне список дел на сегодня 3
# Введите через пробел числа, которые нужно сложить: 3 5
# 8
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-30ca252e8566> in <cell line: 3>()
#       2 h=''
#       3 while True:
# ----> 4   a=input('Здравствуйте, что я могу для вас сделать? 1) посоветуй музыку 2) посоветуй фильм 3) сложи числа 4) составь мне список дел на сегодня ')
#       5   movies=['Гарри Поттер', 'Брюс Всемогущий', 'Шоу Трумана', 'Браби', 'Платформа', 'Запрос в друзья', 'Я легенда', 'Война миров z', 'Пункт назначения']
#       6   music=['Love Me', 'Seventh Heaven', 'All You Need Is Love', 'Mockingbird', 'What I Meant To Say', 'The Winner Takes It All', 'Should I Stay Or Should I Go', 'Let It Be', 'Farewell']
#
# ...

# %% [markdown]
# # **Задача 4.**

# %% [markdown]
# Камень, ножницы, бумага
#
# Создайте игру в Камень, ножницы, бумагу, в которой пользователь может играть против компьютера. Программа должна запросить выбор пользователя, а затем сгенерировать выбор компьютера. Затем программа должна определить победителя на основе правил игры.
#
# **Этап 1:**
#
# Определение победителя
#
# **Этап 2:**
#
# Игра до 3 побед
#
#
# Ввод для "Этап 1":
#
# ```
# Камень
# ```
#
# Вывод:
#
# ```
# Компьютер: Ножницы
# Игрок: Камень
# Победа: Игрок
# ```

# %%
from random import *
print('Сейчас вы сыграете в игру камень ножницы бумага против бота')
I=0
B=0
bot=['камень', 'ножницы', 'бумага']
while I<3 and B<3:
  print('счёт: ', I, '-', B)
  print()
  i=input('введите камень, ножницы или бумага: ')
  b=choice(bot)
  print(b)
  if i=='камень' and b=='бумага':
    B+=1
    print('вы проиграли:( Бот выбрал бумагу')
  if i=='камень' and b=='ножницы':
    I+=1
    print('Вы победили! Бот выбрал ножницы')
  if i=='камень' and b=='камень':
    print('ничья! Бот тоже выбрал камень')
  if i=='бумага' and b=='бумага':
    print('ничья! Бот тоже выбрал бумагу')
  if i=='бумага' and b=='ножницы':
    B+=1
    print('вы проиграли:( Бот выбрал ножницы')
  if i=='бумага' and b=='камень':
    I+=1
    print('Вы победили! Бот выбрал камень')
  if i=='ножницы' and b=='бумага':
    I+=1
    print('Вы победили! Бот выбрал бумагу')
  if i=='ножницы' and b=='ножницы':
    print('ничья! Бот тоже выбрал ножницы')
  if i=='ножницы' and b=='камень':
    B+=1
    print('вы проиграли:( Бот выбрал камень')
  if I==3:
    print('Итог игры: Победой со счётом: ', I, '-', B)
  if B==3:
    print('Итог игры: Вы проиграли со счётом: ', I, '-', B)
# Out:
# Сейчас вы сыграете в игру камень ножницы бумага против бота
# счёт:  0 - 0
#
# бумага
# вы проиграли:( Бот выбрал бумагу
# счёт:  0 - 1

# %% [markdown]
# # **Задача 5.**

# %% [markdown]
# Создайте игру "Палач" или "Виселица", в которой пользователь должен угадать слово, предлагая буквы. Программа должна выбрать случайное слово, а затем разрешить пользователю угадывать буквы. После каждого угадывания программа должна сообщать пользователю, есть ли в слове буква или нет.
#
# **Этап 1**
# Создать саму игру (игра должна иметь привлекательный интерфейс, соотвесвующий классической висилице)
#
# **Этап 2:**
# Ввести подсчет количества очков и ограничения на попытки
#
# **Этап 3:** Добавить возможность сразу угадать слово

# %%
from random import *
k=0
words=['бегемот', 'трактор', 'стакан', 'покер', 'наушники', 'ручка', 'пакет', 'помидор', 'зарядник', 'храм', 'пустышка', 'элемент', 'квадрокоптер', 'банка', 'подвал', 'фармацевт']
while True:
  if k==2 or k==3 or k==4:
    print(f'Вы угадали уже {k} слова')
  if k==1:
    print(f'Вы угадали уже {k} слово')
  if k>=5:
    print(f'Вы угадали уже {k} слов')
  a=input('сейчас мы сыграем в игру под названием виселица, вы готовы? (Пишите все маленькими буквами) ')
  if a=='да' or a=='Да' or 'готов' in a:
    A=choice(words)
    B=A
    print(f'Попытайтесь угадать загаданное слово за 8 попыток, называя по 1 букве, если же хотите угадать слово целиком, то вместо буквы введите: угадать слово. Количсетво букв в загаданном слове = {len(A)}')
    i=8
    n=[]
    while i>=0:
      if (i==5 or i==6 or i==7 or i==8):
        print(f'У вас есть еще {i} попыток')
      if (i==2 or i==3 or i==4):
        print(f'У вас есть еще {i} попытки')
      if i==0:
        print(f'К сожалению вы пориграли, загаданное слово: {B}')
        break
      if i>1:
        a1=input('Назовите букву: ')
      if i==1:
        a1=input('Это ваша последняя попытка угадать все буквы: ')
      if a1=='угадать слово':
        O1=input('Введите загаданное слово: ')
        if O1==A:
          k+=1
          print('Поздравляю, вы угадали слово!')
          break
        else:
          print(f'К сожалению, вы проиграли, загаданное слово: {B}')
          break

      if a1 not in A:
        i-=1
        print(f'Буквы {a1} нет в загаданном слове')
      if a1 in A:
        A=A.replace(a1, '')
        if len(A)>0:
          print(f'Вы угадали букву, осталось угадать еще {len(A)}')
        if len(A)==0:
          print('Поздравляю, вы угадали все буквы в слове: ', B)
          k+=1
          break
# Out:
# Попытайтесь угадать загаданное слово за 8 попыток, называя по 1 букве, если же хотите угадать слово целиком, то вместо буквы введите: угадать слово. Количсетво букв в загаданном слове = 6
# У вас есть еще 8 попыток
# Буквы п нет в загаданном слове
# У вас есть еще 7 попыток
# Вы угадали букву, осталось угадать еще 4
# У вас есть еще 7 попыток
# Буквы д нет в загаданном слове
# У вас есть еще 6 попыток
# Буквы е нет в загаданном слове
# У вас есть еще 5 попыток
# Буквы у нет в загаданном слове
# У вас есть еще 4 попытки
# Буквы р нет в загаданном слове
# У вас есть еще 3 попытки
# Буквы ы нет в загаданном слове
# У вас есть еще 2 попытки
# Буквы у нет в загаданном слове
# Буквы л нет в загаданном слове
# К сожалению вы пориграли, загаданное слово: стакан
# Попытайтесь угадать загаданное слово за 8 попыток, называя по 1 букве, если же хотите угадать слово целиком, то вместо буквы введите: угадать слово. Количсетво букв в загаданном слове = 7
# У вас есть еще 8 попыток
# ...

# %% [markdown]
# # **Дополнительно: Задача 6.**

# %% [markdown]
# **Цифра на определенном месте:**
#
# Последовательно записан натуральный ряд чисел.
#
# Какая цифра стоит в N позиции
#
#
# Вввод:
#
# ```
# Введите номер позиции: 1234567890
# ```
#
# Вывод:
#
# ```
# 8
# ```

# %%
n=int(input())
#до первого break я постарался сократить время работы основной программы с помощтю сокращения диапазона перебора
k=0#введем переменную для подсчета суммы ряда чисел
for i in range(1000):# введем цикл который поможет рассчитать размерность числа в котором находится n позиция
    if k<n:
        k+=9*(10**i)*(i+1)#считается количество цифр до момента, пока она не станет больше нашей позиции n
    if k>=n:
        k-=9*(10**i)*(i+1)#нижняя граница суммы
        K=n-k#находим количество цифр которое нужно перебрать в нашем диапазоне
        break
m=K
for i in range(10**i, 10**(i+1)): #перебираем тот диапазон, который мы определили выше
    S=str(i)
    m-=len(S) #вычитаем длину числа до тех пор, пока m не станет меньшн либо равной 0
    if m<=0: #И если в позиции остался ноль, значит мы пришли к нужному числу.
        print(S[-1-abs(m)]) #выводим нашу цифру по позиции в которой она находится
        break
#время работы не знаю как еще понизить, пример выводит +-30 сек
# Out:
# 1234567890
# 8
