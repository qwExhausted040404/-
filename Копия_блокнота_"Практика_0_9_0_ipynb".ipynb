# %% [markdown]
# <a href="https://colab.research.google.com/github/qwExhausted040404/-/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B0_0_9_0_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ФИО

# %%
Тумаков Тимофей Кириллович

# %% [markdown]
# # Дисклеймер

# %% [markdown]
# В данной практике вам необходимо применить все ваши знания по темам:
#
# - Функции
# - Словари
# - Списки
# - Множества
# - Условные конструкции
# - Запросы
#
# и все что было изучено на прошлых практических занятиях
#
# В каждом задании кратко описаны функции, которые необходимо реализовать, детали реализации вы должны продумать самостоятельно

# %% [markdown]
# # Задание 0

# %% [markdown]
# Создайте функцию по нахождению уникальных элементов из двух списков
#
#
#
# ```
# a = [1, 2, 3, 4]
# b = [3, 4, 5, 6]
# ```

# %%
def f(a, b):
  A = a + b
  B = []
  for i in A:
    if i not in B:
      B.append(i)
  return B


a = [1, 2, 3, 4]
b = [3, 4, 5, 6]
print(f(a, b))
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# # Задание 1

# %% [markdown]
# Симулятор виртуального питомца
#
# Цель: создать виртуальный симулятор домашних животных, в котором пользователи смогут заводить питомцев и ухаживать за ними.
#
# Требования:
#
# - Функция для усыновления питомца (имя, тип, возраст).
# - Функция для того, чтобы покормить питомца, поиграть с ним или уложить его спать.
# - Функция для отображения состояния питомца (голод, радость, энергия).

# %%
from random import *


def play(moves):# игра в камень ножницы бумага с питомцем
  print('Сейчас вы сыграете в игру камень ножницы бумага c питомцем')
  I = 0
  B = 0
  while I<3 and B<3:
    print('счёт: ', I, '-', B)
    print()
    i = input('введите камень, ножницы или бумага: ')
    m = choices(moves)
    b = m[0]
    if i == 'камень' and b=='бумага':
      B += 1
      print('вы проиграли:( питомец выбрал бумагу')
    elif i == 'камень' and b=='ножницы':
      I += 1
      print('Вы победили! питомец выбрал камень')
    elif i == 'камень' and b=='камень':
      print('ничья! питомец тоже выбрал камень')
    elif i == 'бумага' and b=='бумага':
      print('ничья! питомец тоже выбрал бумагу')
    elif i == 'бумага' and b=='ножницы':
      B += 1
      print('вы проиграли:( питомец выбрал ножницы')
    elif i == 'бумага' and b=='камень':
      I += 1
      print('Вы победили! питомец выбрал камень')
    elif i == 'ножницы' and b=='бумага':
      I += 1
      print('Вы победили! питомец выбрал бумагу')
    elif i == 'ножницы' and b=='ножницы':
      print('ничья! питомец тоже выбрал ножницы')
    elif i == 'ножницы' and b=='камень':
      B += 1
      print('вы проиграли:( питомец выбрал камень')
    if I == 3:
      return('Итог игры: Победой со счётом: ', I, '-', B)
    if B == 3:
      return('Итог игры: Вы проиграли со счётом: ', I, '-', B)


def characteristic(name, types, age, count):
  if name not in name_pets:
    if pets == {}:
      pets['name'] = list()
      pets['name'].append(name)
      pets['types'] = list()
      pets['types'].append(types)
      pets['age'] = list()
      pets['age'].append(age)
      pets['eat'] = list()
      pets['eat'].append('Голоден')
      pets['emotions'] = list()
      pets['emotions'].append('Грустно')
      pets['energy'] = list()
      pets['energy'].append('Устал')
      print(f'Новый питомец - {name}! Теперь у вас есть {count} питомец')
    else:
      pets['name'].append(name)
      pets['types'].append(types)
      pets['age'].append(age)
      pets['eat'].append('Голоден')
      pets['emotions'].append('Грустно')
      pets['energy'].append('Устал')
      if 2<= count <= 4:
        print(f'Новый питомец - {name}! Теперь у вас есть {count} питомца')
      elif count > 4:
        print(f'Новый питомец - {name}! Теперь у вас есть {count} питомцев')
  else:
    name1 = input('Питомец с данным именем уже существует! Давайте придумаем новое имя: ')
    characteristic(name1, types, age, count)
  return pets


def state(name):# определяет состояние питомца по позиции в словаре
  for i in range(len(pets['name'])):
    if pets['name'][i] == name:
      a = pets['eat'][i]
      b = pets['emotions'][i]
      c = pets['energy'][i]
      number_pet.append(i)
  return a, b, c

eats = ['морковка', 'капуста', 'яблоко', 'огурчик', 'банан', 'пельмени', 'горошек', 'салат']
pets = {}
count = 0
name_pets = []# для проверки, существует ли такой питомец
number_pet = []#хранит индивидуальную позицию питомца в словаре всех питомцев
moves = ['камень', 'ножницы', 'бумага']

while True:
  choice = int(input('Что вы хотите сделать? 1) Усыновить питомца 2) Взаимодействовать с питомцем 3) посмотреть состояние питомца '))
  if choice == 1:
    name = input('Введите имя питомца: ')
    count += 1
    types = input('Введите тип питомца: ')
    age = int(input('Введите возраст питомца: '))
    pet = characteristic(name, types, age, count)
    name_pets.append(name)
  if choice == 2:
    choice_1 = int(input('выберете взаимодействие: 1)покормить 2)поиграть 3) уложить спать '))
    if choice_1 == 1:
      name_eat = input('Введите имя питомца, которого хотите покормить: ')
      if name_eat not in name_pets:
        print('Питомец с данным именем отсутствует! ')
      else:
        eat_1 = choices(eats)
        #eats.remove(eat_1)
        eat_2 = choices(eats)
        #eats.remove(eat_2)
        eat_3 = choices(eats)
        #eats.remove(eat_3)
        eat = int(input(f'чем хотите покормить питомца? 1) {eat_1[0]} 2) {eat_2[0]} 3) {eat_3[0]} '))
        if eat == 1:
          print(f'{name_eat}: Спасибо! Очень вкусно! обожаю {eat_1[0]}')
        if eat == 2:
          print(f'{name_eat}: Спасибо! Очень вкусно! обожаю {eat_2[0]}')
        if eat == 3:
          print(f'{name_eat}: Спасибо! Очень вкусно! обожаю {eat_3[0]}')
        number_pet = []
        state(name_eat)
        pets['eat'][number_pet[0]] = 'Сыт'
    if choice_1 == 2:
      name_2 = input('С каким питомцем вы хотите поиграть? введите имя ')
      if name_2 not in name_pets:
        print('Питомец с данным именем отсутсвует! ')
      else:
        number_pet = []
        state(name_2)
        play(moves)
        pets['emotions'][number_pet[0]] = 'Радостно'
        print(f'Теперь питомцу {name_2} радостно! ')
    if choice_1 == 3:
      name_sleep = input('Какого питомца нужно уложить спать? ')
      if name_sleep not in name_pets:
        print('Питомец с таким именем отсутствует! ')
      else:
        print(f'{name_sleep}: Спокойной ночи, любимый хозяин! ')
        number_pet = []
        state(name_sleep)
        pets['energy'][number_pet[0]] = 'Полон сил'
  if choice == 3:
    name_1 = input('Состояние какого питомца хотите посмотреть? введите имя ')
    if name_1 not in name_pets:
      print('Питомец с таким именем отсутствует! ')
    else:
      A, B, C = state(name_1)
      print(f'{name_1} {A}, ему {B} и он {C}')
# Out:
# Новый питомец - милена! Теперь у вас есть 1 питомец
# Сейчас вы сыграете в игру камень ножницы бумага c питомцем
# счёт:  0 - 0
#
# Вы победили! питомец выбрал камень
# счёт:  1 - 0
#
# ничья! питомец тоже выбрал ножницы
# счёт:  1 - 0
#
# Вы победили! питомец выбрал камень
# счёт:  2 - 0
#
# ничья! питомец тоже выбрал бумагу
# счёт:  2 - 0

# %% [markdown]
# # Задание 2

# %% [markdown]
# Рыцарь и дракон
#
# Цель: создать небольшую игру, в которой вам необходимо играть за рыцаря и сразиться с драконом
#
# Требования:
#
# - Создание персонажа (имя, информация о доспехах, оружии, урон, здоровье)
# - Управление персонажем и мини сюжет
# - Создание дракона (Имя, информация о здоровье и уроне)
# - Боевая система (нанесение и получение урона, урон должен быть случайным в заданном диапазоне)
# - Реализовать бой между драконом и рыцарем

# %%
from random import *

def fight(HP_knight, HP_dragon, min_damage_knight, max_damage_knight,\
          min_damage_dragon, max_damage_dragon, spell, name, dragon_equipment): # реализует бой с драконом
  print(f'У дракона {HP_dragon} HP, а у вашего рыцаря - {name} {HP_knight} HP')
  print('Вы намерены нанести первый удар дракону неожиданно!')
  m1 = m2 = 0 #переменные для контроля заклятий
  dragon_name = dragon_equipment['имя']
  while HP_knight > 0 and HP_dragon > 0:
    if spell != 0:
      spell_fight = int(input(f'у вас есть {spell} заклятия. Использовать? 1) да 2) нет '))
      if spell_fight == 1:
        m1+=1
        print('Вы использовали заклятие на дракона и оглушили его на один ход! ')
        spell -= 1
    attack = input(f'Атакуйте {dragon_name}a (напишите "атаковать") ').lower()
    if attack != 'атаковать':
      return f'Вы растерялись и {dragon_name} сжег вас '
    attack_knight = randint(min_damage_knight, max_damage_knight)# задается рандомный урон обоим персонажам
    attack_dragon = randint(min_damage_dragon, max_damage_dragon)
    print(f'{name} порезал {dragon_name}a и снял ему {attack_knight} HP')
    HP_dragon -= attack_knight
    print()
    if HP_dragon > 0:
      print(f'У {dragon_name}а осталось {HP_dragon} HP')
    else:
      return('Вы нанесли решающий удар и успешно победили дракона! ')
      break
    print()
    if m1 != m2:
      print(f'{dragon_name} лежит без сознания и пропускает ход')
      m2+=1
    else:
      if 4<= randint(1, 10) <= 10:# с 30% вероятностью доспехи поглотят половину урона
        print(f'Дракон атаковал вас и доспехи не смогли защитить вас.\
        {dragon_name} снял вам {attack_dragon} HP')
        HP_knight -= attack_dragon
        print()
      else:
        print(f'Ваши доспехи защитили вас и поглотили половину урона! полученный урон составил {attack_dragon//2}')
        HP_knight -= attack_dragon//2
    if HP_knight > 0:
      print(f'у {name} осталось {HP_knight} HP')
    else:
      return (f'{dragon_name} сразил вас и вы погибли !')
      break


name = input('Дайте имя своему рыцарю: ')
knight_equipment =  {'доспехи':{'Описание':'Доспехи Теневого Стража выполнены из\
легкой, но прочной кожи, \nобработанной специальным способом, чтобы она стала водо-\
и огнеупорной. \nОни идеально облегают тело, не стесняя движений, и при этом\
обеспечивают надежную защиту. \nЧерный и глубокий синий цвета, переплетенные вместе,\
создают эффект, словно доспехи поглощают свет, \nпозволяя носителю сливаться с окружением\
', 'защита': 'с шансом 30% понижает полученный урон в два раза'}, 'оружие\
': {'Описание' : 'Этот великолепный меч, выкованный в сверкающем свете луны\
, \nобьединяет в себе силу ночи и тайны. Его лезвие, выполненное из редкого металла\
, \nпереливается черными и серебряными нитями, создавая иллюзию затмения\
. ', 'урон':'постоянный урон в диапазоне от 12 до 18,\
есть шанс 40% на удвоенный урон'}, 'здоровье': 100}

dragon_equipment = {'имя': 'Муртаг', 'урон': 12, 'здоровье': 100}

info_game = 'Вы доблестный рыцарь, который жил не тужил, но в один момент злой\
\nдракон украл вашу сестру и вы намерены спасти ее, и отправились в дальнюю дорогу.\
\nДракон успел улететь на 20 километров от вас, каждый ход вы кидаете шестигранный\
\nкубик, каждая единица равняется 1 километру. Вам нужно добраться к дракону за 7\
\n6 ходов, иначе дракону добавится 50 HP.  на каждом ходу вас может ждать опасность\
\nили улучшение. Удачи!'

situation = ['Вы попали в ловушку и потеряли 10 HP', 'вы успешно совершили ход'\
, 'вы встретили огра и отрубили ему голову, ваш меч поломался и стал наносить на 2 урона меньше'\
, 'вы встретили фею, которая дала вам зелье, теперь у вас на 5 HP больше'\
,'в вас прилетел камень, вы теряете сознание и теряете один ход'\
, 'вы встретиил кузнеца который улучшил урон вашего меча на 2'\
, 'вы встретили ведьму, которая дала вам заклятие, способное обезвредить дракона на один ход во время битвы']

cube = [1, 2, 3, 4, 5, 6]# варианты ходов
HP_knight = knight_equipment['здоровье']
HP_dragon = 100
min_damage_knight = 12
max_damage_knight = 18
min_damage_dragon = 12
max_damage_dragon = 18
steps = 7# допустимое количество шагов до момента пока дракон не набрал силы
distance_to_dragon = 20
m = 0
spell = 0 # количество заклинаний
fight_end = ''#контроль над окончанием игры

while fight_end == '':
  move = int(input('Что вы хотите сделать? 1) посмоотреть информацию о рыцаре\
  2)посмотреть информацию о драконе 3) прочитать сюжет и правила\
  4) бросить кубик '))
  if move == 1:
    chapter = int(input('Какую информуцию вы хотите посмотреть? 1) описание доспех\
  2)защита доспех 3) описание оружия 4) урон оружия 5)HP рыцаря '))
    if chapter == 1:
      print(knight_equipment['доспехи']['Описание'])
    if chapter == 2:
      print(knight_equipment['доспехи']['защита'])
    if chapter == 3:
      print(knight_equipment['оружие']['Описание'])
    if chapter == 4:
      print(knight_equipment['оружие']['урон'])
    if chapter == 5:
      print(HP_knight)
  if move == 2:
    chapter = int(input('Какую информуцию вы хотите посмотреть? 1) имя\
  2)урон 3) HP дракона '))
    if chapter == 1:
      print(dragon_equipment['имя'])
    if chapter == 2:
      print(dragon_equipment['урон'])
    if chapter == 3:
      print(dragon_equipment['здоровье'])
  if move == 3:
    print(info_game)
  if move == 4:
    steps -= 1
    cube_1 = choices(cube)
    situation_1 = choices(situation)
    if steps > 0:
      print(f'Осталось шагов до успешного похода к дракону: {steps}')
    else:
      m += 1
      if m == 1:
        print('Вы шли слишком долго, теперь у дракона на 50 HP больше! ')
        HP_dragon += 50
    distance_to_dragon -= cube_1[0]
    if distance_to_dragon > 0:
      print(f'Вам выпало {cube_1[0]}. до дракона осталось {distance_to_dragon} км')
      if situation_1[0] == 'Вы попали в ловушку и потеряли 10 HP':
        print(situation_1[0])
        HP_knight -= 10
      if situation_1[0] == 'вы успешно совершили ход':
        print(situation_1[0])
      if situation_1[0] == 'вы встретили огра и отрубили ему голову, ваш меч поломался и стал наносить на 2 урона меньше':
        print('вы встретили огра и отрубили ему голову, ваш меч поломался и стал наносить на 2 урона меньше')
        min_damage_knight -=2
        max_damage_knight -= 2
      if situation_1[0] == 'вы встретили фею, которая дала вам зелье, теперь у вас на 5 HP больше':
        print(situation_1[0])
        HP_knight += 5
      if situation_1[0] == 'в вас прилетел камень, вы теряете сознание и теряете один ход':
        print(situation_1[0])
        steps -= 1
      if situation_1[0] == 'вы встретиил кузнеца который улучшил урон вашего меча на 2':
        print('вы встретиил кузнеца который улучшил урон вашего меча на 2')
        min_damage_knight += 2
        max_damage_knight += 2
      if situation_1[0] == 'вы встретили ведьму, которая дала вам заклятие, способное обезвредить дракона на один ход во время битвы':
        print(situation_1[0])
        spell += 1
        print(f'Теперь у вас {spell} заклятие')
    else:
      print(f'Вам выпало {cube_1[0]}. Вы успешно дошли до дракона, теперь нужно сразиться с ним!')
      print()
      itog = fight(HP_knight, HP_dragon, min_damage_knight, max_damage_knight, min_damage_dragon, max_damage_dragon, spell, name, dragon_equipment)
      print(itog)
      fight_end += 'end'
# Out:
# Дайте имя своему рыцарю: укйиу
# Что вы хотите сделать? 1) посмоотреть информацию о рыцаре  2)посмотреть информацию о драконе 3) прочитать сюжет и правила  4) бросить кубик 4
# Осталось шагов до успешного похода к дракону: 6
# Вам выпало 5. до дракона осталось 15 км
# вы встретили ведьму, которая дала вам заклятие, способное обезвредить дракона на один ход во время битвы
# Теперь у вас 1 заклятие
# Что вы хотите сделать? 1) посмоотреть информацию о рыцаре  2)посмотреть информацию о драконе 3) прочитать сюжет и правила  4) бросить кубик 4
# Осталось шагов до успешного похода к дракону: 5
# Вам выпало 2. до дракона осталось 13 км
# вы успешно совершили ход
# Что вы хотите сделать? 1) посмоотреть информацию о рыцаре  2)посмотреть информацию о драконе 3) прочитать сюжет и правила  4) бросить кубик 4
# Осталось шагов до успешного похода к дракону: 4
# Вам выпало 3. до дракона осталось 10 км
# Вы попали в ловушку и потеряли 10 HP
# ...

# %% [markdown]
# # Задание 3

# %% [markdown]
# Цель - создать менеджера команды Pokémon, который позволит пользователям:
#
# - Добавлять покемонов в свою команду. (если такого покемона еще нет в команде)
# - Удалять покемонов из их команды.
# - Просматривать подробную информацию обо всех покемонах в команде.
# - Находить покемона по имени.
# - Устраивать тренировочный бой между двумя покемонами
#
# Для данной задачи используйте: https://pokeapi.co/

# %%
# Out:
# Pikachu добавлен в команду!
# Charmander добавлен в команду!
# Pikachu (HP: 35, Attack: 55, Defense: 40)
# Charmander (HP: 39, Attack: 52, Defense: 43)
# Charmander удален из команды.
# Pikachu (HP: 35, Attack: 55, Defense: 40)
# Один или оба покемона не найдены в команде.
